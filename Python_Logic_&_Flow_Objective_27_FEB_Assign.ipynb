# %% [markdown]
# <a href="https://colab.research.google.com/github/Babukanth/Assignment_2602/blob/main/Python_Logic_%26_Flow_Objective_27_FEB_Assign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment validation

# %%
num = 7
if num % 3 ==0:
  if num % 5 ==0:
    result = "Fizzbuzz"
  else:
    result = "Fizz"
elif num % 5 == 0:
    result = "Buzz"
else:
    result = str(num)
print(result)
# Out:
# 7

# %%
if 0: print('Excu')

# %%
if "0: print('Excu')
# Out:
#   File "/tmp/ipython-input-384/3613025060.py", line 1
#     if "0: print('Excu')
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
if'False': print('Excu')
# Out:
# Excu

# %%
if 1: print('Excu')
# Out:
# Excu

# %%
x = '5'
y = 3
z = x + str(y)
w = int(x) * y
if w > 10:
  output = z + '!'
else:
  output = z + '?'
print(output)
# Out:
# 53!

# %%
10==10.0
# Out:
# True

# %%
age = 18
has_license = True
if age >= 18 or has_license:
  status = 'Can drive'
elif age >= 18:
  status = 'need license'
else:
  status='Too Young'
print(status)
# Out:
# Can drive

# %%
x = 5
y = 2
result = x / y
print(type(result))
# Out:
# <class 'float'>

# %%
a = 10
b = 3

result1 = a // b
result2 = a % b
print(result1)
print(result2)
print(result1 + result2)
# Out:
# 3
# 1
# 4
